# %% [markdown]
# <a href="https://colab.research.google.com/github/ChamupathiDev/SL-4050-DL_LAB_01_IT22098764/blob/main/Task2_it22098764.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Au_nanoparticle_dataset.csv")

# %%
#drop the data

filtered_data=data.drop(columns=[ 'N_total', 'N_bulk',
'N_surface','R_avg'])

# %%
filtered_data.head(20)
# Out:
#     ID    T       tau  time        Volume    R_min    R_max   R_diff   R_std  \
# 0    1  273  0.000025     1  2.710000e-26  15.5898  19.4516   3.8618  0.6230
# 1    2  273  0.000025     2  2.780000e-26  15.3996  24.1755   8.7760  0.9295
# 2    3  273  0.000025     3  7.850000e-26  21.9199  31.0305   9.1106  1.0701
# 3    4  273  0.000025     4  1.220000e-25  23.2542  37.8795  14.6253  2.3732
# 4    5  273  0.000025     5  1.860000e-25  27.1200  39.7614  12.6415  1.9397
# 5    6  273  0.000025     6  2.260000e-25  33.2496  42.9612   9.7116  1.0219
# 6    7  273  0.000025     7  2.340000e-25  33.6164  41.6168   8.0004  0.8979
# 7    8  273  0.000025     8  2.360000e-25  34.5185  41.4386   6.9201  0.8595
# 8    9  273  0.000025     9  2.370000e-25  34.7525  41.5998   6.8473  0.8483
# 9   10  273  0.000025    10  2.380000e-25  34.7870  41.5401   6.7531  0.8308
# 10  11  273  0.000050     1  2.600000e-26  15.0408  18.6580   3.6172  0.6360
# ...

# %%
#4
features=[ 'N_total', 'N_bulk',
'N_surface','R_avg']
selected_df=data[features]

# %%
selected_df
# Out:
#       N_total  N_bulk  N_surface    R_avg
# 0        1599    1014        585  17.3706
# 1        1642    1034        608  17.6061
# 2        4637    3365       1272  25.3692
# 3        7189    5292       1897  29.7011
# 4       11004    8508       2496  34.2831
# ...       ...     ...        ...      ...
# 3995     1509     950        559  17.4079
# 3996     2315    1469        846  21.2937
# 3997     2764    1905        859  21.4990
# 3998     3148    2199        949  22.5111
# 3999     3986    2785       1201  25.5906
#
# [4000 rows x 4 columns]

# %%
statistic=selected_df.describe()

# %%
statistic
# Out:
#             N_total        N_bulk   N_surface        R_avg
# count   4000.000000   4000.000000  4000.00000  4000.000000
# mean    3476.786500   2521.550250   955.23625    20.654363
# std     3679.286769   2976.232459   721.87022     7.610716
# min      236.000000     89.000000   137.00000     8.528600
# 25%     1061.000000    618.750000   437.00000    15.160725
# 50%     1867.000000   1199.000000   666.00000    18.629250
# 75%     4503.000000   3183.000000  1301.75000    25.525125
# max    14277.000000  11580.000000  3190.00000    39.239200

# %%
results=pd.DataFrame({
    'Feature':features,
    'Mean':selected_df.mean().values,
    'Std Dev':selected_df.std().values,
    'Q1 (25%)':selected_df.quantile(0.25).values,
    'Median (50%)':selected_df.quantile(0.5).values,
    'Q3 (75%)': selected_df.quantile(0.75).values
})

# %%
results
# Out:
#      Feature         Mean      Std Dev     Q1 (25%)  Median (50%)     Q3 (75%)
# 0    N_total  3476.786500  3679.286769  1061.000000    1867.00000  4503.000000
# 1     N_bulk  2521.550250  2976.232459   618.750000    1199.00000  3183.000000
# 2  N_surface   955.236250   721.870220   437.000000     666.00000  1301.750000
# 3      R_avg    20.654363     7.610716    15.160725      18.62925    25.525125

# %%
plt.figure(figsize=(16,4))
for i,feature in enumerate(features,1):
    plt.subplot(1,4,i)
    plt.hist(data[feature],bins=15,color='skyblue',edgecolor='black',alpha=0.7)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')


plt.tight_layout()
plt.show()

# %%
#5
plt.figure(figsize=(12,10))
pair_grid=sns.pairplot(selected_df,
                       diag_kind='hist',
                       plot_kws={'alpha':0.6,
                                 'edgecolor':'k',
                                 's':40},
                       diag_kws={'bins':15,
                                 'edgecolor':'black',
                                 'alpha':0.7})

# %%
pair_grid

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Load the dataset
df = pd.read_csv('Au_nanoparticle_dataset.csv')

# 2. Select the 4 features of interest
features = ['N_total', 'N_bulk', 'N_surface', 'R_avg']
selected_df = df[features]

# 3. Create enhanced pairplot
plt.figure(figsize=(12, 10))
pair_grid = sns.pairplot(selected_df,
                        diag_kind='hist',  # Histograms on diagonal
                        plot_kws={'alpha': 0.6,  # Scatter plot transparency
                                 'edgecolor': 'k',  # Point edges
                                 's': 40},  # Point size
                        diag_kws={'bins': 15,  # Histogram bins
                                 'color': 'gold',  # Histogram color
                                 'edgecolor': 'black',  # Bar edges
                                 'alpha': 0.7})

# 4. Add correlation coefficients to scatter plots
for i, row in enumerate(pair_grid.axes):
    for j, ax in enumerate(row):
        if i != j:  # Skip diagonal (histograms)
            # Calculate Pearson correlation
            corr = selected_df.iloc[:, j].corr(selected_df.iloc[:, i])
            ax.annotate(f'ρ = {corr:.2f}',
                       xy=(0.7, 0.9),
                       xycoords='axes fraction',
                       fontsize=10,
                       bbox=dict(boxstyle='round',
                               facecolor='white',
                               alpha=0.8))



plt.suptitle('Pairwise Relationships in Gold Nanopracticel Dataset',
             y=1.02,
             fontsize=14)

plt.tight_layout()
plt.show()

# %%
new_df=data[features]

# %%
new_df
# Out:
#       N_total  N_bulk  N_surface    R_avg
# 0        1599    1014        585  17.3706
# 1        1642    1034        608  17.6061
# 2        4637    3365       1272  25.3692
# 3        7189    5292       1897  29.7011
# 4       11004    8508       2496  34.2831
# ...       ...     ...        ...      ...
# 3995     1509     950        559  17.4079
# 3996     2315    1469        846  21.2937
# 3997     2764    1905        859  21.4990
# 3998     3148    2199        949  22.5111
# 3999     3986    2785       1201  25.5906
#
# [4000 rows x 4 columns]

# %%
new_df = data[features]

# Create PairGrid with requested modifications
g = sns.PairGrid(new_df)

# 1. Upper triangle: Bivariate histograms
g.map_upper(sns.histplot)

# 2. Diagonal: Histograms with KDE
g.map_diag(sns.histplot, kde=True, color='gold', alpha=0.7)

# 3. Lower triangle: Bivariate KDE plots
g.map_lower(sns.kdeplot, fill=True, cmap='Blues', alpha=0.6)

# Adjust layout
plt.tight_layout()
plt.show()
